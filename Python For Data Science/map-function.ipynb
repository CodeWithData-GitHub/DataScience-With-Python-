# %% [markdown]
# Introduction to map() function :
#
# --> map() is a functional programming tool in python used to :
#             apply a function to all the items of an iterable like list, tuple ect and return a map object .
#
# --> It does not modify original data , just take them process and transforms them .
#
# --> It performs element wise transformation

# %%
# Syntax of map() functions
   map(function, iterable)
